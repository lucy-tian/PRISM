# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/lucytian/data/1_Single_Cell_PRS/2_cV2F/mvp_afr_0.9_0.01/20231221/406k_geno_v2_UKB_18PCs/fit_w_val/LIVER/INI20030780/snpnet.eval.tsv.gz', sep='\t', compression='gzip')

# %%
df
# Out:
#       #response          predictors metric      eval    l_eval    u_eval  \
# 0   INI20030780  covars_INI20030780     R2  0.068343  0.066669  0.070017
# 1   INI20030780  covars_INI20030780     R2  0.068485  0.066694  0.070276
# 2   INI20030780  covars_INI20030780     R2  0.067368  0.062663  0.072073
# 3   INI20030780  covars_INI20030780     R2  0.067880  0.064542  0.071218
# 4   INI20030780  covars_INI20030780     R2  0.063905  0.060341  0.067469
# 5   INI20030780  covars_INI20030780     R2  0.077458  0.058772  0.096144
# 6   INI20030780  covars_INI20030780     R2  0.075140  0.064039  0.086241
# 7   INI20030780  covars_INI20030780     R2  0.020552  0.004794  0.036310
# 8   INI20030780  covars_INI20030780     R2  0.027734  0.011313  0.044155
# 9   INI20030780  covars_INI20030780     R2  0.063948  0.058907  0.068990
# 10  INI20030780  covars_INI20030780     R2  0.056145  0.033162  0.079128
# 11  INI20030780  covars_INI20030780     R2  0.077194  0.061323  0.093065
# ...
