# %%
import pandas as pd
import numpy as np

# %%
pheno_dict = {'INI30120' : 'blood_count', 'INI20030780': 'blood_biochemistry', 'INI1003063':'spirometry', 'INI50030700': 'blood_biochemistry'}

# %%
Afr_val_test = pd.read_csv('Afr_val_test.keep', sep='\t', header=None)
Afr_val_test.columns = ['#FID', 'IID']

# %%
Afr_test = pd.read_csv('/net/bmc-lab5/data/kellis/group/tanigawa/data/ukb21942/sqc/population.20220316/Afr_test.keep', sep='\t', header=None)
Afr_test.columns = ['#FID', 'IID']

# %%
for p in ['INI30120', 'INI20030780', 'INI1003063', 'INI50030700']:
    pheno_df = pd.read_csv(f'/net/bmc-lab5/data/kellis/group/tanigawa/data/ukb21942/pheno/{pheno_dict[p]}.tsv.gz', compression='gzip', sep='\t')
    to_save = pheno_df[['#FID', 'IID', p]].merge(Afr_test[['#FID', 'IID']], on=['#FID', 'IID']).rename(columns={'#FID': 'FID', p:'PHENO'})
    to_save = to_save.dropna()
    to_save.to_csv(f'pheno/test_val_{p}.pheno.txt', header=True, index=False, sep='\t')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 5
#       3 to_save = pheno_df[['#FID', 'IID', p]].merge(Afr_test[['#FID', 'IID']], on=['#FID', 'IID']).rename(columns={'#FID': 'FID', p:'PHENO'})
#       4 to_save = to_save.dropna()
# ----> 5 to_save.to_csv(f'pheno/test_val_{p}.pheno.txt', header=True, index=False, sep='\t')
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
# ...

# %%
for p in ['INI30120', 'INI20030780', 'INI1003063', 'INI50030700']:
    pheno_df = pd.read_csv(f'/net/bmc-lab5/data/kellis/group/tanigawa/data/ukb21942/pheno/{pheno_dict[p]}.tsv.gz', compression='gzip', sep='\t')
    to_save = pheno_df[['#FID', 'IID', p]].merge(Afr_test[['#FID', 'IID']], on=['#FID', 'IID']).rename(columns={'#FID': 'FID', p:'PHENO'})
    to_save = to_save.dropna()
    to_save.to_csv(f'pheno/test_{p}.pheno.txt', header=True, index=False, sep='\t')
